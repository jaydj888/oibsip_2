# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('Unemployment in India.csv')

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.shape
# Out:
# (768, 7)

# %%
df.size
# Out:
# 5376

# %%
df.isna().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-633337079cd0> in <cell line: 1>()
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.size
# Out:
# 5180

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
df.describe(include='all')
# Out:
#                 Region         Date  Frequency  \
# count              740          740        740
# unique              28           14          2
# top     Andhra Pradesh   31-10-2019    Monthly
# freq                28           55        381
# mean               NaN          NaN        NaN
# std                NaN          NaN        NaN
# min                NaN          NaN        NaN
# 25%                NaN          NaN        NaN
# 50%                NaN          NaN        NaN
# 75%                NaN          NaN        NaN
# max                NaN          NaN        NaN
#
#          Estimated Unemployment Rate (%)   Estimated Employed  \
# count                         740.000000         7.400000e+02
# unique                               NaN                  NaN
# top                                  NaN                  NaN
# freq                                 NaN                  NaN
# mean                           11.787946         7.204460e+06
# std                            10.721298         8.087988e+06
# min                             0.000000         4.942000e+04
# 25%                             4.657500         1.190404e+06
# 50%                             8.350000         4.744178e+06
# 75%                            15.887500         1.127549e+07
# max                            76.740000         4.577751e+07
#
#          Estimated Labour Participation Rate (%)   Area
# count                                 740.000000    740
# unique                                       NaN      2
# top                                          NaN  Urban
# freq                                         NaN    381
# mean                                   42.630122    NaN
# std                                     8.111094    NaN
# min                                    13.330000    NaN
# 25%                                    38.062500    NaN
# 50%                                    41.160000    NaN
# 75%                                    45.505000    NaN
# max                                    72.570000    NaN

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated_Unemployment_Rate_(%)',
#        'Estimated_Employed', 'Estimated_Labour_Participation_Rate_(%)',
#        'Area'],
#       dtype='object')

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Region'].value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
px.bar(df,x=df['Region'].value_counts().keys(),y=df['Region'].value_counts(),color=df['Region'].value_counts().keys(),title='Region Counts')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="47e74a79-349a-4541-ad84-8ea09d08f565" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47e74a79-349a-4541-ad84-8ea09d08f565")) {                    Plotly.newPlot(                        "47e74a79-349a-4541-ad84-8ea09d08f565",                        [{"alignmentgroup":"True","hovertemplate":"color=Andhra Pradesh<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kerala<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Kerala","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Kerala","offsetgroup":"Kerala","orientation":"v","showlegend":true,"textposition":"auto","x":["Kerala"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=West Bengal<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"West Bengal","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"West Bengal","offsetgroup":"West Bengal","orientation":"v","showlegend":true,"textposition":"auto","x":["West Bengal"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Uttar Pradesh<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Uttar Pradesh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Uttar Pradesh","offsetgroup":"Uttar Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Uttar Pradesh"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Tripura<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Tripura","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Tripura","offsetgroup":"Tripura","orientation":"v","showlegend":true,"textposition":"auto","x":["Tripura"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Telangana<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Telangana","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Telangana","offsetgroup":"Telangana","orientation":"v","showlegend":true,"textposition":"auto","x":["Telangana"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Tamil Nadu<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Tamil Nadu","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Tamil Nadu","offsetgroup":"Tamil Nadu","orientation":"v","showlegend":true,"textposition":"auto","x":["Tamil Nadu"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Rajasthan<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Rajasthan","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Rajasthan","offsetgroup":"Rajasthan","orientation":"v","showlegend":true,"textposition":"auto","x":["Rajasthan"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Punjab<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Punjab","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Punjab","offsetgroup":"Punjab","orientation":"v","showlegend":true,"textposition":"auto","x":["Punjab"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Odisha<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Odisha","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Odisha","offsetgroup":"Odisha","orientation":"v","showlegend":true,"textposition":"auto","x":["Odisha"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color ...

# %%
px.pie(df,names=df['Region'].value_counts().keys(),values=df['Region'].value_counts(),color=df['Region'].value_counts().keys(),title='Region/age ratio')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9d569a34-4420-4a98-8ea3-79b05ac04c10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d569a34-4420-4a98-8ea3-79b05ac04c10")) {                    Plotly.newPlot(                        "9d569a34-4420-4a98-8ea3-79b05ac04c10",                        [{"customdata":[["Andhra Pradesh"],["Kerala"],["West Bengal"],["Uttar Pradesh"],["Tripura"],["Telangana"],["Tamil Nadu"],["Rajasthan"],["Punjab"],["Odisha"],["Madhya Pradesh"],["Maharashtra"],["Karnataka"],["Jharkhand"],["Himachal Pradesh"],["Haryana"],["Gujarat"],["Delhi"],["Chhattisgarh"],["Bihar"],["Meghalaya"],["Uttarakhand"],["Assam"],["Puducherry"],["Goa"],["Jammu & Kashmir"],["Sikkim"],["Chandigarh"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<br>color=%{customdata[0]}<extra></extra>","labels":["Andhra Pradesh","Kerala","West Bengal","Uttar Pradesh","Tripura","Telangana","Tamil Nadu","Rajasthan","Punjab","Odisha","Madhya Pradesh","Maharashtra","Karnataka","Jharkhand","Himachal Pradesh","Haryana","Gujarat","Delhi","Chhattisgarh","Bihar","Meghalaya","Uttarakhand","Assam","Puducherry","Goa","Jammu & Kashmir","Sikkim","Chandigarh"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880"]},"name":"","showlegend":true,"values":[28,28,28,28,28,28,28,28,28,28,28,28,28,28,28,28,28,28,28,28,27,27,26,26,24,21,17,12],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface ...

# %%
px.bar(df,x=df['Area'].value_counts().keys(),y=df['Area'].value_counts(),color=df['Area'].value_counts().keys(),title='Area Counts')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e470000f-4219-4468-855f-9f50ebc7862f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e470000f-4219-4468-855f-9f50ebc7862f")) {                    Plotly.newPlot(                        "e470000f-4219-4468-855f-9f50ebc7862f",                        [{"alignmentgroup":"True","hovertemplate":"color=Urban<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Urban","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Urban","offsetgroup":"Urban","orientation":"v","showlegend":true,"textposition":"auto","x":["Urban"],"xaxis":"x","y":[381],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Rural<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Rural","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Rural","offsetgroup":"Rural","orientation":"v","showlegend":true,"textposition":"auto","x":["Rural"],"xaxis":"x","y":[359],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"c ...

# %%
px.pie(df,names=df['Area'].value_counts().keys(),values=df['Area'].value_counts(),color=df['Area'].value_counts().keys(),title='Area/age ratio')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="330d1ea4-6c0c-494c-874a-3e177b96ed5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("330d1ea4-6c0c-494c-874a-3e177b96ed5a")) {                    Plotly.newPlot(                        "330d1ea4-6c0c-494c-874a-3e177b96ed5a",                        [{"customdata":[["Urban"],["Rural"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<br>color=%{customdata[0]}<extra></extra>","labels":["Urban","Rural"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B"]},"name":"","showlegend":true,"values":[381,359],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outline ...

# %%
import datetime as dt

# %%
df['Month']=df['Date'].dt.month_name()

# %%
df['Year']=df['Date'].dt.year

# %%
df.drop(['Frequency'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            Region       Date  Estimated_Unemployment_Rate_(%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
#
#    Estimated_Employed  Estimated_Labour_Participation_Rate_(%)   Area  \
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
#
#        Month  Year
# 0        May  2019
# 1       June  2019
# 2       July  2019
# 3     August  2019
# 4  September  2019

# %%
df['Year'].value_counts(normalize=True)*100
# Out:
# 2019    58.108108
# 2020    41.891892
# Name: Year, dtype: float64

# %%
df['Month'].value_counts()
# Out:
# May          105
# June         104
# October       55
# November      55
# July          54
# August        53
# December      53
# January       53
# February      53
# September     52
# March         52
# April         51
# Name: Month, dtype: int64

# %%
px.bar(df,x=df['Month'].value_counts().keys(),y=df['Month'].value_counts(),color=df['Month'].value_counts().keys(),title='Month Counts')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="16b1adb9-9ed6-41b3-b05c-31641cd4ff9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16b1adb9-9ed6-41b3-b05c-31641cd4ff9e")) {                    Plotly.newPlot(                        "16b1adb9-9ed6-41b3-b05c-31641cd4ff9e",                        [{"alignmentgroup":"True","hovertemplate":"color=May<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"May","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"May","offsetgroup":"May","orientation":"v","showlegend":true,"textposition":"auto","x":["May"],"xaxis":"x","y":[105],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=June<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"June","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"June","offsetgroup":"June","orientation":"v","showlegend":true,"textposition":"auto","x":["June"],"xaxis":"x","y":[104],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=October<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"October","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"October","offsetgroup":"October","orientation":"v","showlegend":true,"textposition":"auto","x":["October"],"xaxis":"x","y":[55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=November<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"November","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"November","offsetgroup":"November","orientation":"v","showlegend":true,"textposition":"auto","x":["November"],"xaxis":"x","y":[55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=July<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"July","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"July","offsetgroup":"July","orientation":"v","showlegend":true,"textposition":"auto","x":["July"],"xaxis":"x","y":[54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=August<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"August","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"August","offsetgroup":"August","orientation":"v","showlegend":true,"textposition":"auto","x":["August"],"xaxis":"x","y":[53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=December<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"December","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"December","offsetgroup":"December","orientation":"v","showlegend":true,"textposition":"auto","x":["December"],"xaxis":"x","y":[53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=January<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"January","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"January","offsetgroup":"January","orientation":"v","showlegend":true,"textposition":"auto","x":["January"],"xaxis":"x","y":[53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=February<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"February","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"February","offsetgroup":"February","orientation":"v","showlegend":true,"textposition":"auto","x":["February"],"xaxis":"x","y":[53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=September<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"September","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"September","offsetgroup":"September","orientation":"v","showlegend":true,"textposition":"auto","x":["September"],"xaxis":"x","y":[52],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=March<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"March","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"March"," ...

# %%
px.pie(df,names=df['Month'].value_counts().keys(),values=df['Month'].value_counts(),color=df['Month'].value_counts().keys(),title='Month/age ratio')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="783fa4c8-c9d2-450c-b447-9e81cc48f9ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("783fa4c8-c9d2-450c-b447-9e81cc48f9ff")) {                    Plotly.newPlot(                        "783fa4c8-c9d2-450c-b447-9e81cc48f9ff",                        [{"customdata":[["May"],["June"],["October"],["November"],["July"],["August"],["December"],["January"],["February"],["September"],["March"],["April"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<br>color=%{customdata[0]}<extra></extra>","labels":["May","June","October","November","July","August","December","January","February","September","March","April"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa","#EF553B"]},"name":"","showlegend":true,"values":[105,104,55,55,54,53,53,53,53,52,52,51],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"er ...

# %%
df_region_rate=df.groupby(['Region','Year']).agg({"Estimated_Unemployment_Rate_(%)":'mean'}).reset_index()
df_region_rate.sort_values(by='Estimated_Unemployment_Rate_(%)',ascending=False)
# Out:
#               Region  Year  Estimated_Unemployment_Rate_(%)
# 17           Haryana  2020                        30.929167
# 23         Jharkhand  2020                        29.053333
# 48           Tripura  2019                        28.363125
# 49           Tripura  2020                        28.333333
# 5              Bihar  2020                        25.632500
# 37        Puducherry  2020                        23.840000
# 16           Haryana  2019                        22.798750
# 11             Delhi  2020                        20.155000
# 18  Himachal Pradesh  2019                        19.064375
# 19  Himachal Pradesh  2020                        17.841667
# 45        Tamil Nadu  2020                        17.578333
# 41         Rajasthan  2020                        16.400833
# 7         Chandigarh  2020                        16.330000
# 21   Jammu & Kashmir  2020                        16.251111
# 20   Jammu & Kashmir  2019                        16.141667
# 6         Chandigarh  2019                        15.822500
# 51     Uttar Pradesh  2020                        14.769167
# 22         Jharkhand  2019                        14.233750
# 27            Kerala  2020                        14.114167
# 4              Bihar  2019                        13.882500
# 10             Delhi  2019                        13.750625
# 39            Punjab  2020                        13.562500
# 47         Telangana  2020                        12.567500
# 40         Rajasthan  2019                        12.301250
# 9       Chhattisgarh  2020                        11.765000
# 25         Karnataka  2020                        11.259167
# 1     Andhra Pradesh  2020                        11.010833
# 29    Madhya Pradesh  2020                        10.897500
# 50     Uttar Pradesh  2019                        10.888125
# 38            Punjab  2019                        10.882500
# 31       Maharashtra  2020                        10.355000
# 55       West Bengal  2020                        10.123333
# 12               Goa  2019                         9.346250
# 13               Goa  2020                         9.130000
# 43            Sikkim  2020                         9.068333
# 15           Gujarat  2020                         8.910000
# 35            Odisha  2020                         8.320000
# 53       Uttarakhand  2020                         7.720909
# 8       Chhattisgarh  2019                         7.346875
# 26            Kerala  2019                         7.131250
# 54       West Bengal  2019                         6.625625
# 3              Assam  2020                         6.438182
# 2              Assam  2019                         6.420667
# 42            Sikkim  2019                         6.257273
# 33         Meghalaya  2020                         5.942727
# 52       Uttarakhand  2019                         5.800625
# 30       Maharashtra  2019                         5.459375
# 14           Gujarat  2019                         4.979375
# 0     Andhra Pradesh  2019                         4.826875
# 28    Madhya Pradesh  2019                         4.788125
# 46         Telangana  2019                         4.115625
# 32         Meghalaya  2019                         4.012500
# 34            Odisha  2019                         3.661250
# 24         Karnataka  2019                         3.238750
# 44        Tamil Nadu  2019                         3.063750
# 36        Puducherry  2019                         1.699375

# %%
plt.figure(figsize=(15,10))
plt.title("Average Unemployment Rate In All Regions In Year(2019-2020)")
sns.barplot(data=df_region_rate,y='Region',x='Estimated_Unemployment_Rate_(%)',hue='Year')
# Out:
# <Axes: title={'center': 'Average Unemployment Rate In All Regions In Year(2019-2020)'}, xlabel='Estimated_Unemployment_Rate_(%)', ylabel='Region'>

# %%
df.head()
# Out:
#            Region       Date  Estimated_Unemployment_Rate_(%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
# 2  Andhra Pradesh 2019-07-31                             3.75
# 3  Andhra Pradesh 2019-08-31                             3.32
# 4  Andhra Pradesh 2019-09-30                             5.17
#
#    Estimated_Employed  Estimated_Labour_Participation_Rate_(%)   Area  \
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural
#
#        Month  Year
# 0        May  2019
# 1       June  2019
# 2       July  2019
# 3     August  2019
# 4  September  2019

# %%
df_region_emp=df.groupby(['Region','Year']).agg({"Estimated_Employed":'mean'}).reset_index()
df_region_emp.sort_values(by='Estimated_Employed',ascending=False)
# Out:
#               Region  Year  Estimated_Employed
# 50     Uttar Pradesh  2019        2.852497e+07
# 51     Uttar Pradesh  2020        2.752132e+07
# 30       Maharashtra  2019        2.101646e+07
# 31       Maharashtra  2020        1.862185e+07
# 54       West Bengal  2019        1.795374e+07
# 55       West Bengal  2020        1.619160e+07
# 44        Tamil Nadu  2019        1.394580e+07
# 4              Bihar  2019        1.323785e+07
# 14           Gujarat  2019        1.190651e+07
# 28    Madhya Pradesh  2019        1.147777e+07
# 5              Bihar  2020        1.120397e+07
# 24         Karnataka  2019        1.075008e+07
# 15           Gujarat  2020        1.072935e+07
# 29    Madhya Pradesh  2020        1.063243e+07
# 25         Karnataka  2020        1.055650e+07
# 40         Rajasthan  2019        1.018783e+07
# 45        Tamil Nadu  2020        1.003455e+07
# 41         Rajasthan  2020        9.845378e+06
# 0     Andhra Pradesh  2019        8.402043e+06
# 46         Telangana  2019        8.392168e+06
# 1     Andhra Pradesh  2020        7.823493e+06
# 47         Telangana  2020        7.336322e+06
# 34            Odisha  2019        7.003220e+06
# 35            Odisha  2020        5.935783e+06
# 2              Assam  2019        5.508148e+06
# 3              Assam  2020        5.145623e+06
# 26            Kerala  2019        4.803638e+06
# 22         Jharkhand  2019        4.798559e+06
# 38            Punjab  2019        4.788320e+06
# 8       Chhattisgarh  2019        4.483388e+06
# 39            Punjab  2020        4.207418e+06
# 9       Chhattisgarh  2020        4.063647e+06
# 23         Jharkhand  2020        4.030149e+06
# 27            Kerala  2020        3.922248e+06
# 16           Haryana  2019        3.731464e+06
# 17           Haryana  2020        3.324551e+06
# 10             Delhi  2019        2.896461e+06
# 11             Delhi  2020        2.268915e+06
# 20   Jammu & Kashmir  2019        1.838242e+06
# 21   Jammu & Kashmir  2020        1.748851e+06
# 52       Uttarakhand  2019        1.427203e+06
# 53       Uttarakhand  2020        1.336447e+06
# 18  Himachal Pradesh  2019        1.108268e+06
# 19  Himachal Pradesh  2020        9.952317e+05
# 48           Tripura  2019        7.316091e+05
# 49           Tripura  2020        6.975273e+05
# 33         Meghalaya  2020        6.955085e+05
# 32         Meghalaya  2019        6.857688e+05
# 6         Chandigarh  2019        3.208352e+05
# 7         Chandigarh  2020        3.088232e+05
# 36        Puducherry  2019        2.330804e+05
# 12               Goa  2019        2.268961e+05
# 13               Goa  2020        2.251329e+05
# 37        Puducherry  2020        1.789944e+05
# 42            Sikkim  2019        1.111313e+05
# 43            Sikkim  2020        9.908800e+04

# %%
plt.figure(figsize=(15,10))
plt.title("Average Employment In All Regions In Year(2019-2020)")
sns.barplot(data=df_region_emp,y='Region',x='Estimated_Employed',hue='Year')
# Out:
# <Axes: title={'center': 'Average Employment In All Regions In Year(2019-2020)'}, xlabel='Estimated_Employed', ylabel='Region'>

# %%
df_region_area=df.groupby(['Area','Year']).agg({"Estimated_Unemployment_Rate_(%)":'mean'}).reset_index()
df_region_area.sort_values(by='Estimated_Unemployment_Rate_(%)',ascending=False)
# Out:
#     Area  Year  Estimated_Unemployment_Rate_(%)
# 3  Urban  2020                        16.654528
# 1  Rural  2020                        13.466358
# 2  Urban  2019                        10.668514
# 0  Rural  2019                         8.044135

# %%
df_region_ar_em=df.groupby(['Area','Year']).agg({"Estimated_Employed":'mean'}).reset_index()
df_region_ar_em.sort_values(by='Estimated_Employed',ascending=False)
# Out:
#     Area  Year  Estimated_Employed
# 0  Rural  2019        1.049050e+07
# 1  Rural  2020        9.782849e+06
# 2  Urban  2019        4.548901e+06
# 3  Urban  2020        4.164845e+06

# %%
plt.figure(figsize=(15,10))
plt.title("Average Employment In All Areas In Year(2019-2020)")
sns.barplot(data=df_region_ar_em,y='Area',x='Estimated_Employed',hue='Year')
# Out:
# <Axes: title={'center': 'Average Employment In All Areas In Year(2019-2020)'}, xlabel='Estimated_Employed', ylabel='Area'>
